# %% [markdown]
# <a href="https://colab.research.google.com/github/AlekyaMadiReddy/Alekya_INFO5731_Fall2023/blob/main/In_class_exercise_02_09_13_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The second In-class-exercise (09/13/2023, 40 points in total)

# %% [markdown]
# Kindly use the provided .ipynb document to write your code or respond to the questions. Avoid generating a new file.
# Execute all the cells before your final submission.

# %% [markdown]
# This in-class exercise is due tomorrow September 14, 2023 at 11:59 PM. No late submissions will be considered.

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question or something innovative) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:
I bought an Macbook from flipkart website.I want to collect the reviews of the laptop.
To get this data, I have used two Python libraries - BeautifulSoup and Requests. I have written the steps I have did to collect the data.
 I have taken the for loop to iterate it through all the pages and to  get the required page, I have used requests Pyhthon library.
 I have used beautiful soup to collect the data and used the inspect element to find out the class names for the title of the reviews and for the full text.
 To display the data, I have used data frame.




'''
# Out:
# '\nPlease write you answer here:\nI bought an Macbook from flipkart website.I want to collect the reviews of the laptop.\nTo get this data, I have used two Python libraries - BeautifulSoup and Requests. I have written the steps I have did to collect the data.\n I have taken the for loop to iterate it through all the pages and to  get the required page, I have used requests Pyhthon library.\n I have used beautiful soup to collect the data and used the inspect element to find out the class names for the title of the reviews and for the full text.\n To display the data, I have used data frame. \n\n\n\n\n'

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):
# Import necessary libraries
from bs4 import BeautifulSoup
import requests
import pandas
title = []
fullReview =[]
# Loop to scrape data from multiple pages (70 in this case)
for i in range(70):
  URL = "https://www.flipkart.com/apple-2020-macbook-air-m1-8-gb-256-gb-ssd-mac-os-big-sur-mgn63hn-a/p/itm3c872f9e67bc6?pid=COMFXEKMGNHZYFH9&lid=LSTCOMFXEKMGNHZYFH9P56X45&marketplace=FLIPKART&q=macbook&store=6bo%2Fb5g&srno=s_1_1&otracker=search&otracker1=search&fm=search-autosuggest&iid=b5a555c9-768c-4559-bfe9-446fca83be8d.COMFXEKMGNHZYFH9.SEARCH&ppt=sp&ppn=sp&ssid=to0qougjg00000001694919311787&qH=864faee128623e2f" + str(i)
  webPage = requests.get(URL)   # Send an HTTP GET request to the URL
  beautifulSoup = BeautifulSoup(webPage.text, 'html.parser')   # Parse the HTML content of the webpage using BeautifulSoup
  title_text = beautifulSoup.find_all(class_='_2-N8zT')     # Find all elements with class '_2-N8zT' (presumably titles)
  fullReview_text = beautifulSoup.find_all(class_='t-ZTKy')
   # Iterate through pairs of title and full review elements and append them to the respective lists
  for ele1, ele2 in zip(title_text, fullReview_text):
      title.append(ele1.text)
      fullReview.append(ele2.text) # Create a DataFrame to store the scraped data
res = pandas.DataFrame(list(zip(title, fullReview)), columns =['Title', 'Full text review'])
res
# Out:
#                     Title                                   Full text review
# 0             Good choice  Value for money product...But no one said this...
# 1         Value-for-money  A bit expensive when we compare with  today's ...
# 2               Excellent  About  me (type of consumer): moved from windo...
# 3               Brilliant            Best device ever .I love it...READ MORE
# 4               Brilliant                  Best in class laptop ❤️💫READ MORE
# ..                    ...                                                ...
# 695        Classy product  Fantastic value for money machine!! Absolute b...
# 696        Simply awesome  My first Macbook and no regret that I waited f...
# 697         Great product                                UnbeatableREAD MORE
# 698             Wonderful           Just love it, dream comes true😎READ MORE
# 699  Good quality product  Great LaptopWas almost about to buy an 360 tou...
#
# [700 rows x 2 columns]

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2013-2023).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
import requests
from bs4 import BeautifulSoup

# Function to scrape and print articles from a given URL
def scrape_articles(url):
    response = requests.get(url)  # Send a GET request to the URL
    soup = BeautifulSoup(response.text, 'html.parser')   # Use BeautifulSoup to extract the page's HTML content.
    articles = soup.find_all('div', class_='gs_ri')  # Locate and gather data for each article on the page.

  # Loop through the articles and extract the desired information
    for article in articles:
        title = article.find('h3', class_='gs_rt').text
        venue = article.find('div', class_='gs_a').text.split(' - ')[-1]
        year = article.find('div', class_='gs_a').text.split(' - ')[0]
        authors = article.find('div', class_='gs_a').text.split(' - ')[1]
        abstract = article.find('div', class_='gs_rs').text

        print("Title:", title)
        print("Venue:", venue)
        print("Year:", year)
        print("Authors:", authors)
        print("Abstract:", abstract)
        print("\n---\n")

# Loop through plenty of pages of results to get 1,000 articles.
articles_per_page = 10  # A page of Google Scholar normally shows 10 items.
total_articles = 1000

for page in range(0, total_articles, articles_per_page):
  # URL of Google Scholar search results
    page_url = f"https://scholar.google.com/scholar?hl=en&as_sdt=0%2C44&q=computer+science&btnG=&oq=computer+{page}"
    scrape_articles(page_url)
# Out:
# Streaming output truncated to the last 5000 lines.
# Abstract: … computing to students. Non-majors get an exceptionally lucid view of computing without
# experiencing the “computer science … by all instructors of introductory computer science courses. …
#
# ---
#
# Title: [PDF][PDF] Scientific methods in computer science
# Venue: john.cs.olemiss.edu
# Year: G Dodig-Crnkovic - Proceedings of the Conference for the …, 2002
# Authors: john.cs.olemiss.edu
# Abstract: … This paper analyzes scientific aspects of Computer Science. First it defines science and
# scientific method in general. It gives a discussion of relations between … In spite of all …
#
# ---
#
# Title: [BOOK][B] Guide to teaching computer science
# Venue: Springer
# Year: O Hazzan, T Lapidot, N Ragonis
# Authors: 2020
# Abstract: … in computer science education gained during the past … computer science and on computer
# science education to high school computer science pupils, undergraduate computer science …
#
# ---
#
# ...

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
# Import necessary libraries
import os
import tweepy as tw
import pandas as pd

# Twitter API credentials
key= '879s3Nhbo0eTpEfzw4v8RfuDY'
secret= 'l5ZyARMmQQ0kyGlitj9X4SzzqIw1Bkv1JNKaLItDsBNVgpflYl'
token= '1703296285971775488-dlItTKysxBtm849UuVGdKKPQnuogN3'
access_secret= 'DihqYpMS5wXr9LQH2UhzB1XaQHCBZExkRev49hDfCCOJd'

# Authenticate with Twitter API using Tweepy
authorize = tw.OAuthHandler(key, secret)
authorize.set_access_token(token, access_secret)
api = tw.API(authorize, wait_on_rate_limit=True)

key_word = "#lifestyle"
required_date_from = "2023-09-11"

# Use Tweepy to search for tweets that match the criteria
tweets = tw.Cursor(api.search,
              q=key_word,
              lang="en",
              since=required_date_from).items(1000)

[tweet.text for tweet in tweets]
